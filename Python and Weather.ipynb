# %%
import random
import numpy as np
import timeit
import matplotlib.pyplot as plt
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# for i in range(100):
#     i = random.randint(-1000,1000)
#     print(i)

random_number = random.randint(-90, 90) + random.random()
random_number
# Out:
# 15.215052919134083

# %%
x = 1
latitudes = []
while x < 11:
    random_latitude = random.randint(-90, 89) + random.random()
    latitudes.append(random_latitude)
    x += 1
latitudes
# Out:
# [-43.09962452239842,
#  -17.645345151795947,
#  -66.47875897793139,
#  73.75563047728043,
#  -14.291249395029425,
#  51.66387106092997,
#  -25.994209782307255,
#  -12.536813619222178,
#  63.01232478416711,
#  79.08387451542298]

# %%
for i in range(5):
    i = random.randrange(-90,90, step=3)
    print(i)
# Out:
# -87
# 81
# 42
# -90
# 66

# %%
np.random.uniform(-90, 90, size=50)
# Out:
# array([-68.78171029,  -6.19754913, -42.39517507,  50.3752644 ,
#         77.23700233, -24.51495314, -11.73538068, -53.83559564,
#        -42.73029735,  19.36852003,  76.01963683, -78.50296012,
#         56.33440138, -48.15440537, -71.79107665,  21.54549924,
#        -11.73366244, -48.54876671,  44.04068158,  89.35571466,
#        -56.41728688,  -4.28469511, -71.86297526,  38.89555566,
#        -79.52377733,   1.64944411, -75.13773787,  31.16234553,
#         19.89465308,  -9.87335374,  62.40103795,  23.61584686,
#         38.68204883,  57.4926138 ,  26.66600906,  81.9656175 ,
#         78.32321214,  77.20156842, -34.27778423, -53.45725623,
#         47.64376288, -29.09108867, -20.57577139,  82.18953257,
#        -54.54185563, -23.98178239,  34.6211837 ,  64.93895098,
#        -78.24389502, -21.76336604])

# %%
# %timeit
np.random.uniform(-90, 90, size=1500)
# Out:
# 34.9 µs ± 1.09 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
def latitudes(size):
    latitudes = []
    for i in range(size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
    return latitudes

# %timeit latitudes(1500)
print(latitudes(1500))
# Out:
# 3.76 ms ± 160 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# ...

# %%
latitudes = np.random.uniform(-90, 90, size=1500)
longitudes = np.random.uniform(-90, 90, size=1500)
lat_lngs = zip(latitudes, longitudes)
coordinates = list(lat_lngs)
coordinates
# Out:
# [(5.077692647343909, 60.842777081389215),
#  (-0.3045802681322982, 19.652274006530575),
#  (52.47886522145515, 17.72898491725978),
#  (22.340490537498567, 48.15820451578327),
#  (-4.3877945449962255, -58.60097985844367),
#  (-77.28082122765902, -61.51583495047428),
#  (73.03999665539945, 69.8430548780681),
#  (13.899956804597977, 12.065901538936089),
#  (-34.700528030198534, -72.49045062285418),
#  (-55.27939630062315, -73.59886795563692),
#  (19.893521095781352, -31.372376593098096),
#  (29.883795112218948, -71.77105446242335),
#  (77.33045550324292, -48.24778870019648),
#  (-18.710569474587615, 64.87169460567819),
#  (42.58478126675354, -23.60129148459538),
#  (-7.142703575301908, -72.6267591477538),
#  (79.08764796191281, -78.32727759471307),
#  (4.813849985661108, -30.45256424817844),
#  (88.9471967533591, 13.912166603385998),
#  (67.52580818252659, 5.816721283434987),
#  (-72.43080094433392, -47.43355531229096),
#  (-72.92217372582655, 6.123831849520997),
# ...

# %%
from citipy import citipy as cpy
for coordinate in coordinates[:5]:
    print(cpy.nearest_city(coordinate[0], coordinate[1]).city_name,
         cpy.nearest_city(coordinate[0], coordinate[1]).country_code)
    print(coordinate)
coordinates[1][:2]
# Out:
# bandarbeyla so
# (5.077692647343909, 60.842777081389215)
# boende cd
# (-0.3045802681322982, 19.652274006530575)
# gniezno pl
# (52.47886522145515, 17.72898491725978)
# riyadh sa
# (22.340490537498567, 48.15820451578327)
# nova olinda do norte br
# (-4.3877945449962255, -58.60097985844367)
# (-0.3045802681322982, 19.652274006530575)

# %%
latitudes = np.random.uniform(-90, 90, size=1500)
longitudes = np.random.uniform(-90, 90, size=1500)
lat_lngs = zip(latitudes, longitudes)
coordinates = list(lat_lngs)
cities = []
for coordinate in coordinates:
    city = cpy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
cities

# %%
import time
from datetime import datetime
city_data = []
print('Beginning Data Retrieval')
print('------------------------')

record_count = 1
set_count = 1

for i, city enumerate(cities):
    weather_data = requests.get(city_url)
# Out:
# 629
